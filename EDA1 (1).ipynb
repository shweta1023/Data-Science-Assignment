# %% [markdown]
# # Assignment: EXPLORATORY DATA ANALYSIS ON A DATASET

# %%
import pandas as pd

# %%
# 1.Load the dataset into a Dataframe or equivalent data structure

# %%
data = pd.read_csv("Cardiotocographic.csv")

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
data.info() #find missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
data.shape
# Out:
# (2126, 14)

# %%
data.isnull().sum() # display no.of null values in each column
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
data.duplicated() #display duplicate rows with boolean type True and all
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
data[data.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
data1 = data.drop_duplicates() #remove duplicated rows and save in new var.data1

# %%
data1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data1[data1.duplicated()] #print duplicated rows
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %%
#remove duplicated rows and save in new var.data1

# %%
# After removing duplicated rows from the dataset, now we can treat null values using imputation technique. Imputation technique is used for replacing the missing data with some subtitle values to retain most of the data/information of the dataset. These subtitle values can be either mean, vmedian or mode.Let treat null values of some columns using mean,some columns using median and some columns using mode.
# We can treat null values of columns: LB,AC,DS,DP using mean

# %%
mean = data['LB'].mean()

# %%
mean
# Out:
# 133.3435983550352

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean1 = data['AC'].mean()

# %%
mean1
# Out:
# 0.0032189782438000465

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean2 = data['DS'].mean()

# %%
mean2
# Out:
# 2.5089835057102827e-06

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean3 = data['DP'].mean()

# %%
mean3
# Out:
# 0.00017515121174634704

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Null values of Columns: MLTV, width can be treated using median

# %%
median = data['MLTV'].median()

# %%
median
# Out:
# 7.4

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
median1 = data['Width'].median()

# %%
median1
# Out:
# 67.0

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Null values of columns: Tendency, Nsp can be treated using mode. Use mode specifying it's index position

# %%
mode = data['Tendency'].mode()

# %%
mode
# Out:
# 0    0.0
# Name: Tendency, dtype: float64

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mode1 =data['NSP'].mode()

# %%
mode1
# Out:
# 0    1.0
# Name: NSP, dtype: float64

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).

# %%
data.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# as we can see, data type of each and every column is float64 because each column has numerical values. So,there is no inconsistency in data types.

# %%
# Detect and treat outliers if necessary

# %%
# It will also cover data visualization (Create histograms or boxplots to visualize the distributions of various numerical variables)

# %%
data['LB'].hist()
# Out:
# <Axes: >

# %%
# Range of LB: 0-220. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (55-65). Data is right skewed and we can see outliers within the range (198-218)

# %%
import matplotlib.pyplot as plt #boxplot function available in this lib

# %%
data.boxplot(column='LB')
plt.show()

# %%
# Range of LB: 0-220. Data is both left and right skewed. IQR(Inter Quartile Range)= 140-125 = 15 (approx.). Range from 0-60: 1 outlier which must be removed from the dataset. Range from 200-220: 1 outlier which must be removed from the dataset

# %%
data['AC'].hist()
# Out:
# <Axes: >

# %%
# Range of AC: -0.02 to 0.04. Here,data has both left and right skewness. Data is left skewed and we can see the outliers within the range(-0.02 to-0.01). Data is right skewed and we can see outliers within the range (0.015 to 0.022)

# %%
data.boxplot(column='AC')
plt.show()

# %%
#Range of AC: -0.02 to 0.04. Data is both left and right skewed. IQR(Inter Quartile Range)= 0.005-0.00=0.005 (approx.). Range from -0.02 to -0.01: 1 outlier which must be removed from the dataset.Range from 0.01 to 0.02 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.03 to 0.04: 1 outlier which must be removed from the dataset

# %%
data['FM'].hist()
# Out:
# <Axes: >

# %%
# range of FM: -0.6 to 1.0 . Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.5 to -0.3). Data is right skewed and we can see outliers within the range (0.1 to 0.5)

# %%
data.boxplot(column='FM')
plt.show()

# %%
# Range of FM: -0.6 to 1.0 . Data is both left and right skewed. IQR(Inter Quartile Range)= 0.0 (approx.). Range from -0.6 to -0.4: 1 outlier which must be removed from the dataset.Range from 0.0 to 0.6 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.8 to 1.0: 1 outlier which must be removed from the dataset

# %%
data['UC'].hist()
# Out:
# <Axes: >

# %%
#Range of UC: -0.005 to 0.03 . Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.005 to -0.01). Data is right skewed and we can see outliers within the range (0.012 to 0.017, 0.025 to 0.03)

# %%
data.boxplot(column='UC')
plt.show()

# %%
# Range of UC: -0.005 to 0.03 . Data is both left and right skewed. IQR(Inter Quartile Range)= 0.01 (approx.). Range from -0.005 to -0.01: 1 outlier which must be removed from the dataset.Range from 0.01 to 0.02 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.02 to 0.03: 1 outlier which must be removed from the dataset

# %%
data['DL'].hist()
# Out:
# <Axes: >

# %%
# Range of DL: -0.005 to 0.03 . Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.005 to -0.01). Data is right skewed and we can see outliers within the range (0.012 to 0.017, 0.025 to 0.03)

# %%
data.boxplot(column='DL')
plt.show()

# %%
# column DS

# %%
data['DS'].hist()
# Out:
# <Axes: >

# %%
# Range of DS:-0.0015 to 0.0025. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.0015 to -0.0010). Data is right skewed and we can see outliers within the range(0.0025 to 0.0030)

# %%
data.boxplot(column='DS')
plt.show()

# %%
# column: DP

# %%
data['DP'].hist()
# Out:
# <Axes: >

# %%
# Range of DP:-o.006 to 0.010. Here,data has both has both left and right skewness. Data is left skewed and we can the outliers within the range(-0.006 to -0.004). Data is right skewed and we can see outliers within the range(0.009 to 0.012)

# %%
data.boxplot(column='DP')
plt.show()

# %%
# columns:ASTV

# %%
data['ASTV'].hist()
# Out:
# <Axes: >

# %%
# Range of ASTV:-60 to 150. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-60 to -40). Data is right skewed and we can see outliers within the range(140 to 160)

# %%
data.boxplot(column='ASTV')
plt.show()

# %%
# column MSTV

# %%
data['MSTV'].hist()
# Out:
# <Axes: >

# %%
# Range of MSTV: -7.5 to 12.5 . Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-7.5 to -5.0). Data is right skewed and we can see outliers within the range (5.2 to 7.5, 11 to 12.55)

# %%
data.boxplot(column='MSTV')
plt.show()

# %%
# Column: ALTV

# %%
data['ALTV'].hist()
# Out:
# <Axes: >

# %%
# Range of ALTV: -100 to 150. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-100 to -50). Data is right skewed and we can see outliers within the range (150 to 155)

# %%
data.boxplot(column='ALTV')
plt.show()

# %%
# Column:MLTV

# %%
data['MLTV'].hist()
# Out:
# <Axes: >

# %%
# Range of MLTV:-50 to 100. Data is both left and right skewed. Data is left skewed

# %%
data.boxplot(column='MLTV')
plt.show()

# %%
# Range of MLTV:-50 to 100. Data is both left and right skewed. IQR(Inter Quartile Range)=5(approx). Range from -50 to -40: 1 outlier which must be removed from the dataset. Range from 20 to 60 is very dense,so,we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 100 to 110: 1 outlier which must be removed from the dataset

# %%
# Column Width

# %%
data['Width'].hist()
# Out:
# <Axes: >

# %%
# Range of width: -200 to 300. Data is both left and right skewed. Data is left skewed. Data is left skewed and we can see the outliers within the range(-200 to -100).Data is right skewed and we can see outliers within the range (300-350)

# %%
data.boxplot(column= 'Width')
plt.show()

# %%
# Range of Width: -200 to 300 . Data is both left and right skewed. IQR(Inter Quartile Range)=100-10=90 (approx.). Range from -200 to-100: 1 outlier which must be removed from the dataset. Range from 300 to 350: 1 outlier which must be removed from the dataset

# %%
# Column: Tendency

# %%
data['Tendency'].hist()
# Out:
# <Axes: >

# %%
# Range of Tendency: -3 to 3. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-3 to -2.5). Data is right skewed and we can see outliers within the range (2.5 to 3)

# %%
data.boxplot(column='Tendency')
plt.show()

# %%
# Range of Tendency: -3 to 3 . Data is both left and right skewed. IQR(Inter Quartile Range)=1 (approx.). Range from -3 to-2: 1 outlier which must be removed from the dataset. Range from 2 to 3: 1 outlier which must be removed from the dataset

# %%
# Column: NSP

# %%
data['NSP'].hist()
# Out:
# <Axes: >

# %%
# Range of NSP: -1 to 5. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-1 to -0.5 . Data is right skewed and we can see outliers within the range (4.5 to 5)

# %%
data.boxplot(column='NSP')
plt.show()

# %% [markdown]
# # 2. Statical Summary

# %% [markdown]
# # Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).

# %%
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
mean= data.mean()

# %%
mean
# Out:
# LB          133.343598
# AC            0.003219
# FM            0.009894
# UC            0.004391
# DL            0.001895
# DS            0.000003
# DP            0.000175
# ASTV         46.995984
# MSTV          1.364378
# ALTV         10.285964
# MLTV          8.284887
# Width        70.429260
# Tendency      0.316371
# NSP           1.304507
# dtype: float64

# %%
median= data.median()

# %%
median
# Out:
# LB          133.000000
# AC            0.001634
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.400000
# Width        67.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
from scipy import stats

# %%
stats.mode(data) #calculate mode of all columns
# Out:
# ModeResult(mode=array([133. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ,  65. ,   0.5,
#          0. ,   0. ,  39. ,   0. ,   1. ]), count=array([ 129.,  833., 1232.,  318., 1166., 1985., 1821.,   60.,  116.,
#        1168.,  124.,   42., 1037., 1546.]))

# %%
std= data.std() #std of all columns

# %%
std
# Out:
# LB          11.270154
# AC           0.004391
# FM           0.067540
# UC           0.003340
# DL           0.003343
# DS           0.000142
# DP           0.000840
# ASTV        18.813973
# MSTV         1.173632
# ALTV        21.205041
# MLTV         7.772858
# Width       42.931822
# Tendency     0.645622
# NSP          0.644619
# dtype: float64

# %%
# Inter Quartile Range

# %%
IQR= Q3-Q1

# %%
Q1= data.quantile(0.25)
Q1
# Out:
# LB          126.000000
# AC            0.000000
# FM            0.000000
# UC            0.001851
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         32.000000
# MSTV          0.700000
# ALTV          0.000000
# MLTV          4.600000
# Width        37.000000
# Tendency      0.000000
# NSP           1.000000
# Name: 0.25, dtype: float64

# %%
Q3= data.quantile(0.75)
Q3
# Out:
# LB          140.000000
# AC            0.005650
# FM            0.002567
# UC            0.006536
# DL            0.003289
# DS            0.000000
# DP            0.000000
# ASTV         61.000000
# MSTV          1.700000
# ALTV         11.000000
# MLTV         10.900000
# Width       100.000000
# Tendency      1.000000
# NSP           1.000000
# Name: 0.75, dtype: float64

# %%
IQR= Q3-Q1 #IQR for each numerical column
IQR
# Out:
# LB          14.000000
# AC           0.005650
# FM           0.002567
# UC           0.004685
# DL           0.003289
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.300000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %% [markdown]
# # Highlighting any interesting find from this summary

# %%
# Columns like LB, AC, FM, UC, DL, DS, DL, DP, MSTV, Tendecy, NSP have perfectly normal distributed data (because, mean = median = mode)

# %%
# Column ASTV has left skewed data i.e majority of data lies in the right side of the mean(because, mean > median > mode)

# %%
# Columns like ALTV,MLTV,Width have right skewed data i.e. majority of data lies in the left side of the mean (because, mean > median > mode)

# %%
# If std is more => data is more spread about the mean i.e data points are more far away from the mean. Clearly, for Width,ALTV,ASTV data is relatively more spread about the mean and for DS, DP data is least spread about the mean.

# %%
# If IQR is more => middle 50% data is more spread and if IQR is less => middle 50% data cluster more tightly. Clearly, for Width,ASTV,LB,ALTV middle 50% data is relatively more spread and for DS, DP, NSP middle 50% data cluster more tightly

# %% [markdown]
# # 3. Data Visualization:

# %% [markdown]
# # Create histograms or boxplots to visualize the distributions of various numerical variables.

# %%
data['LB'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='LB')
plt.show()

# %%
data['AC'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='AC')
plt.show()

# %%
data['FM'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='FM')
plt.show()

# %%
data['UC'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='UC')
plt.show()

# %%
data['DL'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='DL')
plt.show()

# %%
data['DS'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='DS')
plt.show()

# %%
data['DP'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='DP')
plt.show()

# %%
data['ASTV'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='ASTV')
plt.show()

# %%
data['MLTV'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='MLTV')
plt.show()

# %%
data['Width'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='Width')
plt.show()

# %%
data['Tendency'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='Tendency')
plt.show()

# %%
data['NSP'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='NSP')
plt.show()

# %% [markdown]
# # ●	Use bar charts or pie charts to display the frequency of categories for categorical variables.

# %%
# In this dataset there is only numerical columns. 
#There is no any categorical column.

# %% [markdown]
# # ●	Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.

# %%
# Scatter plots are used to visualize(without calculation) whether two variables has good correlation or not which means scatter plot just gives us assumption about the correlation between two varibles whereas heatmap gives the exact value of correlation between two variables

# %%
xpoints=data1['LB']
ypoints=data1['NSP']
plt.title('scatterplot')
plt.xlabel('LB')
plt.ylabel('NSP')
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
plt.title('scatter plot')
plt.xlabel('LB')
plt.ylabel('NSP')
plt.scatter(xpoints,ypoints)
plt.show()

# %%
# We can also draw scatter plot using scatterplot function available inside seaborn library.

# %%
import seaborn as sns

# %%
sns.scatterplot(x=data['LB'],y=data['NSP'])
plt.title('scatterplot')
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
sns.scatterplot(x=data1['AC'],y=data1['NSP'])  #using scatterplot func.
plt.title('scatterplot')
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
sns.scatterplot(x=data1['FM'],y=data1['NSP'])  #using scatterplot func.
plt.title('scatterplot')
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
fig, ax = plt.subplots(figsize=(10, 10))  #specify size of heatmap
sns.heatmap(data1.corr(),annot=True) #create heatmap (parameter annot is used
# Out:
# <Axes: >

# %%
#DP, ASTV are the most contributing elements which is increasing the NSP i.e. DP, ASTV are the variables which affect the NSP most because correlation value between DP and NSP is 0.47 which is maximum value shown in this heatmap. Likewise, correlation value between ASTV and NSP is also 0.47. Hence, they have positive correlation (both variable varies in same direction)any value < 0.1 is considered as no-correlation. Therefore, variables like FM, DL have no correlation with NSP. Remaining variables either have negative correlation or very less correlation with NSP (Negative correlation means both variable varies in opposite direction)

# %% [markdown]
# # ●	Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %%
sns.violinplot(x=data['LB']) # it will show the distibution of data inside column LB using violinplot func.
# Out:
# <Axes: xlabel='LB'>

# %%
sns.violinplot(x=data['AC'])
# Out:
# <Axes: xlabel='AC'>

# %%
sns.violinplot(x=data['FM'])
# Out:
# <Axes: xlabel='FM'>

# %%
sns.violinplot(x=data['UC'])
# Out:
# <Axes: xlabel='UC'>

# %%
sns.violinplot(x=data['DL'])
# Out:
# <Axes: xlabel='DL'>

# %%
sns.violinplot(x=data['DS'])
# Out:
# <Axes: xlabel='DS'>

# %%
sns.violinplot(x=data['DP'])
# Out:
# <Axes: xlabel='DP'>

# %%
sns.violinplot(x=data['ASTV'])
# Out:
# <Axes: xlabel='ASTV'>

# %%
sns.violinplot(x=data['MLTV'])
# Out:
# <Axes: xlabel='MLTV'>

# %%
sns.violinplot(x=data['Width'])
# Out:
# <Axes: xlabel='Width'>

# %%
sns.violinplot(x=data['Tendency'])
# Out:
# <Axes: xlabel='Tendency'>

# %%
sns.violinplot(x=data['NSP'])
# Out:
# <Axes: xlabel='NSP'>

# %% [markdown]
# # 4. Pattern Recognition and Insights:

# %% [markdown]
# # ●	Identify any correlations between variables and discuss their potential implications.

# %%
# Look for trends or patterns over time if temporal data is available: for getting the insights of trend or pattern, the dataset must be time series where date column is compulsory. Since, our dataset does not meet the condition, so, we can not give insight of trends here.
# But we can draw the plot between variable LB and NSP to see the slope which is very helpful in determining the trend.
# Lilewise, we can check the slope slope between other variables as well but this is only meaningful with respect to date column.

# %%
sns.lineplot(x=data1['LB'], y=data1['NSP'],label='pattern', color='blue')
 
# Adding labels and title
plt.xlabel('LB')
plt.ylabel('NSP')
plt.title('checking trend')
# Out:
# Text(0.5, 1.0, 'checking trend')

# %%
# if the slope is a +ve value Then increasing trend
# if the slope value is neative then decreasing trend
# if the slope is a zero vlaue then no trend

# %% [markdown]
# # 5. Conclusion

# %%
# A machine learning algorithm can not run if there are missing values, outliers in the dataset. We can treat missing values using Imputation technique.
# Imputation tecnique is used for replacing the missing data with some substitute values to retain most of data/information of th dataset. These subtitle values can be either mean, median or mode.
# After treating missing values, our next goal is to remove the outliers and for it, outlier detection is needed which is done by boxplot. 
# Once we remove outliers,our data becomes normal distributed i.e symmetrical about the mean and now, we are in the position to train our machine learning model sucessfully.
# Through IQR, we will understand how middle 50% data is spread and heatmap will help us to understand whether our variables have good correlation or not which ultimately hepls us in getting close to the future predictions especially when we are working on Time Series data
